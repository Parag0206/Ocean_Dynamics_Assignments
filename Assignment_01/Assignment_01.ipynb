# %% [markdown]
# ### Assignment 1
# To plot the bethymetry of Bay of Bengal and Arabian Sea

# %%
import xarray as xr
import numpy as np 
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
bathy = xr.open_dataset("Indian_Ocean_ETOPO_Modified 2_minute_bathymetry_for_Indian_Ocean.nc")
bathy
# Out:
# <xarray.Dataset>
# Dimensions:       (LON901_2401: 1501, LAT1022_1982: 961, TIME: 1)
# Coordinates:
#   * LON901_2401   (LON901_2401) float64 50.02 50.05 50.08 ... 99.95 99.98 100.0
#   * LAT1022_1982  (LAT1022_1982) float64 -3.984 -3.95 -3.917 ... 27.98 28.02
#   * TIME          (TIME) datetime64[ns] 1999-01-15
# Data variables:
#     TOPO2         (TIME, LAT1022_1982, LON901_2401) float32 ...
# Attributes:
#     history:      FERRET V6.5  16-Jan-24
#     Conventions:  CF-1.0

# %%
bathy["TOPO2"].plot()

# %% [markdown]
# ### Arabian Sea

# %%
AS = bathy["TOPO2"].sel(LON901_2401=slice("55.", "80."))
AS
# Out:
# <xarray.DataArray 'TOPO2' (TIME: 1, LAT1022_1982: 961, LON901_2401: 750)>
# [720750 values with dtype=float32]
# Coordinates:
#   * LON901_2401   (LON901_2401) float64 55.02 55.05 55.08 ... 79.92 79.95 79.98
#   * LAT1022_1982  (LAT1022_1982) float64 -3.984 -3.95 -3.917 ... 27.98 28.02
#   * TIME          (TIME) datetime64[ns] 1999-01-15
# Attributes:
#     long_name:  bathymetry of the indian ocean (m)
#     history:    From io_etopo2

# %%
plt.figure(1, figsize=(10,6))
ax1 = plt.axes(projection=ccrs.PlateCarree())
ax1.coastlines()
AS.plot(cmap="Blues", ax=ax1)
plt.yticks(np.linspace(-4,28,9))
plt.ylabel("Latitude")
plt.xticks(np.linspace(55,80,6))
plt.xlabel("Longitude")
plt.title("Arabian Sea Bathymetry")
plt.savefig("Arabian_Sea_Bathymetry.png")

# %% [markdown]
# ### Bay of Bengal

# %%
BOB = bathy["TOPO2"].sel(LON901_2401=slice("80.", "98."))
BOB
# Out:
# <xarray.DataArray 'TOPO2' (TIME: 1, LAT1022_1982: 961, LON901_2401: 540)>
# [518940 values with dtype=float32]
# Coordinates:
#   * LON901_2401   (LON901_2401) float64 80.02 80.05 80.08 ... 97.92 97.95 97.98
#   * LAT1022_1982  (LAT1022_1982) float64 -3.984 -3.95 -3.917 ... 27.98 28.02
#   * TIME          (TIME) datetime64[ns] 1999-01-15
# Attributes:
#     long_name:  bathymetry of the indian ocean (m)
#     history:    From io_etopo2

# %%
plt.figure(2, figsize=(12,8))
ax2 = plt.axes(projection=ccrs.PlateCarree())
ax2.coastlines()
BOB.plot(cmap="Blues", ax=ax2)
plt.yticks(np.linspace(-4,28,9))
plt.ylabel("Latitude")
plt.xticks(np.linspace(80,98,5))
plt.xlabel("Longitude")
plt.title("Bay of Bengal Bathymetry")
plt.savefig("Bay_of_Bengal_Bathymetry.png")
